# %% [markdown]
# <a href="https://colab.research.google.com/github/abhiakotkar/google_play_store_apps_analysis/blob/main/Copy_of_EDA_CAPSTONE_PROJECT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Introduction**
# ## Google Play Store or formerly android market, is a digital distribution service developed and operated by Google. It is an official apps store that provides variety content such as apps, books, magazines, music, movies and television programs. It serves an platform to allow users with 'Google Certified' Android operating system devices to download applications developed & published on the platform data analysis on the data to obtain valuable insights.
# The dataset is going to be used is 'Google Play Store Apps ' from Almabetter. The tools that are going to be used for this EDA would be 'numpy', 'pandas', 'matplotlib' and 'seaborn' which i have learnt from the full stack almabetter course.

# %% [markdown]
# **DATA PREPARATION & CLEANING**
#
#
# In this section , we will be loading the Google Store Apps data stored in CSV using pandas which is a fast and powerful python library for data analysis and easy data manipulation in pandas Dataframe object. We perfrom some data preparation and also data cleaning on it.

# %%
# Import the necessary libraries.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# look at the files in the dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#load the apps and reviews data into Pandas Dataframe
file_path = ('/content/drive/MyDrive/almaB/capstone_project/capstone_project_/Play Store Data.csv')
df = pd.read_csv(file_path)

# %%
# number of rows and columns in the dataset
df.shape
# Out:
# (10841, 13)

# %%
#look at the first 10 records in the apps dataframe
df.head(10)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4
# 6            Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                   Infinite Painter  ART_AND_DESIGN     4.1
# 8                               Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                      Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
# 5     167  5.6M      50,000+  Free     0       Everyone
# 6     178   19M      50,000+  Free     0       Everyone
# 7   36815   29M   1,000,000+  Free     0       Everyone
# 8   13791   33M   1,000,000+  Free     0       Everyone
# 9     121  3.1M      10,000+  Free     0       Everyone
#
#                       Genres        Last Updated         Current Ver  \
# 0               Art & Design     January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play    January 15, 2018               2.0.0
# 2               Art & Design      August 1, 2018               1.2.4
# 3               Art & Design        June 8, 2018  Varies with device
# 4    Art & Design;Creativity       June 20, 2018                 1.1
# 5               Art & Design      March 26, 2017                 1.0
# 6               Art & Design      April 26, 2018                 1.1
# 7               Art & Design       June 14, 2018            6.1.61.1
# 8               Art & Design  September 20, 2017               2.9.2
# 9    Art & Design;Creativity        July 3, 2018                 2.8
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up
# 5    2.3 and up
# 6  4.0.3 and up
# 7    4.2 and up
# 8    3.0 and up
# 9  4.0.3 and up

# %%
#look at the first 10 records in the apps dataframe
df.tail(10)
# Out:
#                                                  App             Category  \
# 10831                       payermonstationnement.fr  MAPS_AND_NAVIGATION
# 10832                                       FR Tides              WEATHER
# 10833                                    Chemin (fr)  BOOKS_AND_REFERENCE
# 10834                                  FR Calculator               FAMILY
# 10835                                       FR Forms             BUSINESS
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10831     NaN      38                9.8M       5,000+  Free     0
# 10832     3.8    1195                582k     100,000+  Free     0
# 10833     4.8      44                619k       1,000+  Free     0
# 10834     4.0       7                2.6M         500+  Free     0
# 10835     NaN       0                9.6M          10+  Free     0
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres        Last Updated  \
# 10831       Everyone  Maps & Navigation       June 13, 2018
# 10832       Everyone            Weather   February 16, 2014
# 10833       Everyone  Books & Reference      March 23, 2014
# 10834       Everyone          Education       June 18, 2017
# 10835       Everyone           Business  September 29, 2016
# 10836       Everyone          Education       July 25, 2017
# 10837       Everyone          Education        July 6, 2018
# 10838       Everyone            Medical    January 20, 2017
# 10839     Mature 17+  Books & Reference    January 19, 2015
# 10840       Everyone          Lifestyle       July 25, 2018
#
#               Current Ver         Android Ver
# 10831           2.0.148.0          4.0 and up
# 10832                 6.0          2.1 and up
# 10833                 0.8          2.2 and up
# 10834               1.0.0          4.1 and up
# 10835               1.1.5          4.0 and up
# 10836                1.48          4.1 and up
# 10837                 1.0          4.1 and up
# 10838                 1.0          2.2 and up
# 10839  Varies with device  Varies with device
# 10840  Varies with device  Varies with device

# %%
# look at the dataset information based on columns
df.info();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# **Description of App Dataset Columns**
#
#
#
# *    App : The name of the app.
# *  Category : The category of the app.
#
# *   Ratings : The rating of the app in the Play Store.
# *   Reviews : The number of reviews of the app.
#
# *   Size : The size of the app.
# *   Install : The number of the Installs of the app .
#
# *   Type : The type of the app (Free/ Paid)
# *   The price of the app (0 if it is free)
#
# *   Content Ratings : The appropiate target audience of the app.
# *   Generes : The genere of the app
#
# *   Last Updated : The data when the app was last updated.
# *   Current Version : The current version of the app
#
# *   Android Version : The minimum Android version required to run the app.

# %%
df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
df.boxplot();

# %% [markdown]
# This data contain outliers

# %%
df.hist();

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df.isnull()
# Out:
#          App  Category  Rating  Reviews   Size  Installs   Type  Price  \
# 0      False     False   False    False  False     False  False  False
# 1      False     False   False    False  False     False  False  False
# 2      False     False   False    False  False     False  False  False
# 3      False     False   False    False  False     False  False  False
# 4      False     False   False    False  False     False  False  False
# ...      ...       ...     ...      ...    ...       ...    ...    ...
# 10836  False     False   False    False  False     False  False  False
# 10837  False     False   False    False  False     False  False  False
# 10838  False     False    True    False  False     False  False  False
# 10839  False     False   False    False  False     False  False  False
# 10840  False     False   False    False  False     False  False  False
#
#        Content Rating  Genres  Last Updated  Current Ver  Android Ver
# 0               False   False         False        False        False
# 1               False   False         False        False        False
# 2               False   False         False        False        False
# 3               False   False         False        False        False
# 4               False   False         False        False        False
# ...               ...     ...           ...          ...          ...
# 10836           False   False         False        False        False
# 10837           False   False         False        False        False
# 10838           False   False         False        False        False
# 10839           False   False         False        False        False
# 10840           False   False         False        False        False
#
# [10841 rows x 13 columns]

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
df[df.Rating>5]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %% [markdown]
# Here, 10472 row have the rating more than 5 , so it is a outliers because rating cannot be more than 5.

# %%
df.drop([10472],inplace = True)

# %% [markdown]
# Drop the row 10472 from the data.

# %%
df[10470:10475]
# Out:
#                            App         Category  Rating Reviews  Size  \
# 10470               Jazz Wi-Fi    COMMUNICATION     3.4      49  4.0M
# 10471         Xposed Wi-Fi-Pwd  PERSONALIZATION     3.5    1042  404k
# 10473  osmino Wi-Fi: free WiFi            TOOLS     4.2  134203  4.1M
# 10474             Sat-Fi Voice    COMMUNICATION     3.4      37   14M
# 10475         Wi-Fi Visualizer            TOOLS     3.9     132  2.6M
#
#           Installs  Type Price Content Rating           Genres  \
# 10470      10,000+  Free     0       Everyone    Communication
# 10471     100,000+  Free     0       Everyone  Personalization
# 10473  10,000,000+  Free     0       Everyone            Tools
# 10474       1,000+  Free     0       Everyone    Communication
# 10475      50,000+  Free     0       Everyone            Tools
#
#             Last Updated Current Ver   Android Ver
# 10470  February 10, 2017         0.1    2.3 and up
# 10471     August 5, 2014       3.0.0  4.0.3 and up
# 10473     August 7, 2018     6.06.14    4.4 and up
# 10474  November 21, 2014     2.2.1.5    2.2 and up
# 10475       May 17, 2017       0.0.9    2.3 and up

# %%
df.boxplot();

# %% [markdown]
# Now, no outliers are present.

# %% [markdown]
# [italicized text](https://)#**DATA CLEANING**

# %%
# check on null values
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          2
# dtype: int64

# %% [markdown]
# Above data shows the null values in the
#
# 1. Rating
#
#
# 2.   Type
#
#
# 2.   Current Ver.

# %% [markdown]
# NOW, Filling tha null values with median

# %%
def replace_with_median(series):
    """
    Given a series, replace the rows with null values 
    with median values
    """
    return series.fillna(series.median())

df['Rating'] = df['Rating'].transform(replace_with_median)
df['Rating'] = df['Rating'].astype(float)

# %%
# remove the record where 'Type' is having null value
index = df[df['Type'].isnull()].index
df.drop(axis=0, inplace=True, index=index)

# %%
# check on null values
df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       8
# Android Ver       2
# dtype: int64

# %%
df[df['Content Rating'].isnull()]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
df.dropna(subset = ['Content Rating'], inplace = True)

# %% [markdown]
# **CHANGING THE DATA TYPE FROM OBJECT TO THE FLOAT**

# %%
reviews = [i for i in df['Reviews']]

def clean_reviews(reviews_list):
    """
    As 'M' has been found the in reviews data, this function
    replace it with million
    """
    cleaned_data = []
    for review in reviews_list:
        if 'M' in review:
            review = review.replace('M', '')
            review = float(review) * 1000000  # 1M = 1,000,000
        cleaned_data.append(review)
    return cleaned_data

df['Reviews'] = clean_reviews(reviews)
df['Reviews'] = df['Reviews'].astype(float)

# %%
# 2) clean the 'Size' data and change the type 'object' to 'float'

# found value with '1,000+' in one of record, remove it from data_frame as uncertain whether it is 'M' or 'k'
index = df[df['Size'] == '1,000+'].index
df.drop(axis=0, inplace=True, index=index)

sizes = [i for i in df['Size']]

def clean_sizes(sizes_list):
    """
    As sizes are represented in 'M' and 'k', we remove 'M'
    and convert 'k'/kilobytes into megabytes
    """
    cleaned_data = []
    for size in sizes_list:
        if 'M' in size:
            size = size.replace('M', '')
            size = float(size)
        elif 'k' in size:
            size = size.replace('k', '')
            size = float(size)
            size = size/1024  # 1 megabyte = 1024 kilobytes
        # representing 'Varies with device' with value 0
        elif 'Varies with device' in size:
            size = float(0)
        cleaned_data.append(size)
    return cleaned_data

df['Size'] = clean_sizes(sizes)
df['Size'] = df['Size'].astype(float)

# %%
# 3) clean the 'Installs' data and change the type 'object' to 'float'

installs = [i for i in df['Installs']]

def clean_installs(installs_list):
    cleaned_data = []
    for install in installs_list:
        if ',' in install:
            install = install.replace(',', '')
        if '+' in install:
            install = install.replace('+', '')
        install = int(install)
        cleaned_data.append(install)
    return cleaned_data
        
df['Installs'] = clean_installs(installs)
df['Installs'] = df['Installs'].astype(float)

# %%
# 4) clean the 'Price' data and change the type 'object' to 'float'
prices = [i for i in df['Price']]

def clean_prices(prices_list):
    cleaned_data = []
    for price in prices_list:
        if '$' in price:
            price = price.replace('$', '')
        cleaned_data.append(price)
    return cleaned_data

df['Price'] = clean_prices(prices)
df['Price'] = df['Price'].astype(float)

# %%
df.sample(10)
# Out:
#                                 App             Category  Rating    Reviews  \
# 6904                   Learn SAP BW  BOOKS_AND_REFERENCE     4.3        2.0
# 5027                 AE Master Moto                 GAME     4.0    17876.0
# 1799                      Word Link                 GAME     4.6   216675.0
# 5856              Google Play Games               FAMILY     4.3  7168735.0
# 6961      Benefit Extras Mobile App   HEALTH_AND_FITNESS     2.3        3.0
# 9363                     Eh Volevi!               FAMILY     3.9     1619.0
# 277   Asana: organize team projects             BUSINESS     4.3    20815.0
# 8567                       DM הפקות          PHOTOGRAPHY     4.3        2.0
# 2397          Paramedic Pocket Prep              MEDICAL     4.3      460.0
# 5097                   EZ Ag Mobile              FINANCE     3.4       19.0
#
#       Size      Installs  Type  Price Content Rating             Genres  \
# 6904  20.0  5.000000e+02  Free    0.0       Everyone  Books & Reference
# 5027  37.0  1.000000e+06  Free    0.0       Everyone             Racing
# 1799  30.0  1.000000e+07  Free    0.0       Everyone               Word
# 5856   0.0  1.000000e+09  Free    0.0           Teen      Entertainment
# 6961   2.4  1.000000e+03  Free    0.0       Everyone   Health & Fitness
# 9363   7.0  1.000000e+05  Free    0.0       Everyone      Entertainment
# 277   10.0  1.000000e+06  Free    0.0       Everyone           Business
# 8567  10.0  1.000000e+02  Free    0.0       Everyone        Photography
# 2397  13.0  1.000000e+04  Free    0.0       Everyone            Medical
# 5097  24.0  5.000000e+03  Free    0.0       Everyone            Finance
#
#            Last Updated         Current Ver         Android Ver
# 6904  February 13, 2018                 1.1          4.0 and up
# 5027  December 10, 2015               1.8.6          2.3 and up
# 1799     August 1, 2018               2.2.7          4.1 and up
# 5856      July 16, 2018  Varies with device  Varies with device
# 6961      July 18, 2018                 6.0          5.0 and up
# 9363    October 7, 2017               1.2.1          4.0 and up
# 277       July 26, 2018               6.4.4          5.0 and up
# 8567   October 14, 2017                30.0          3.2 and up
# 2397      July 12, 2018               4.5.2          4.4 and up
# 5097    August 12, 2017              9.0.00          3.0 and up

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating   Reviews  Size    Installs  Type  Price Content Rating  \
# 0         4.1     159.0  19.0     10000.0  Free    0.0       Everyone
# 1         3.9     967.0  14.0    500000.0  Free    0.0       Everyone
# 2         4.7   87510.0   8.7   5000000.0  Free    0.0       Everyone
# 3         4.5  215644.0  25.0  50000000.0  Free    0.0           Teen
# 4         4.3     967.0   2.8    100000.0  Free    0.0       Everyone
# ...       ...       ...   ...         ...   ...    ...            ...
# 10836     4.5      38.0  53.0      5000.0  Free    0.0       Everyone
# 10837     5.0       4.0   3.6       100.0  Free    0.0       Everyone
# 10838     4.3       3.0   9.5      1000.0  Free    0.0       Everyone
# 10839     4.5     114.0   0.0      1000.0  Free    0.0     Mature 17+
# 10840     4.5  398307.0  19.0  10000000.0  Free    0.0       Everyone
#
#                           Genres      Last Updated         Current Ver  \
# 0                   Art & Design   January 7, 2018               1.0.0
# 1      Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2                   Art & Design    August 1, 2018               1.2.4
# 3                   Art & Design      June 8, 2018  Varies with device
# 4        Art & Design;Creativity     June 20, 2018                 1.1
# ...                          ...               ...                 ...
# 10836                  Education     July 25, 2017                1.48
# 10837                  Education      July 6, 2018                 1.0
# 10838                    Medical  January 20, 2017                 1.0
# 10839          Books & Reference  January 19, 2015  Varies with device
# 10840                  Lifestyle     July 25, 2018  Varies with device
#
#               Android Ver
# 0            4.0.3 and up
# 1            4.0.3 and up
# 2            4.0.3 and up
# 3              4.2 and up
# 4              4.4 and up
# ...                   ...
# 10836          4.1 and up
# 10837          4.1 and up
# 10838          2.2 and up
# 10839  Varies with device
# 10840  Varies with device
#
# [10839 rows x 13 columns]

# %%
# grouping the data starting with App and Reviews
df = df.groupby(['App', 'Reviews', 'Category', 'Rating', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 
                           'Last Updated', 'Current Ver', 'Android Ver'], as_index=False)
# reassign Installs values with their mean
df = df['Installs'].mean()
# sort the dataframe by Reviews descendingly
df.sort_values(by='Reviews', ascending=False, inplace=True)
# drop duplicate rows based on App 
df.drop_duplicates(subset=['App'], inplace=True)
df
# Out:
#                                              App     Reviews       Category  \
# 4534                                    Facebook  78158306.0         SOCIAL
# 9661                          WhatsApp Messenger  69119316.0  COMMUNICATION
# 5731                                   Instagram  66577446.0         SOCIAL
# 6546    Messenger – Text and Video Chat for Free  56646578.0  COMMUNICATION
# 2701                              Clash of Clans  44893888.0           GAME
# ...                                          ...         ...            ...
# 4372                      FG Autumn Photo Puzzle         0.0         FAMILY
# 4369  FE Other Disciplines Engineering Exam Prep         0.0         FAMILY
# 9033                             Thyroid Nodules         0.0        MEDICAL
# 185                            ACCEPT CE MARKING         0.0   PRODUCTIVITY
# 5862           K-App Mitarbeiter Galeria Kaufhof         0.0   PRODUCTIVITY
#
#       Rating  Size  Type  Price Content Rating         Genres  \
# 4534     4.1   0.0  Free    0.0           Teen         Social
# 9661     4.4   0.0  Free    0.0       Everyone  Communication
# 5731     4.5   0.0  Free    0.0           Teen         Social
# 6546     4.0   0.0  Free    0.0       Everyone  Communication
# 2701     4.6  98.0  Free    0.0   Everyone 10+       Strategy
# ...      ...   ...   ...    ...            ...            ...
# 4372     4.3   4.6  Free    0.0       Everyone         Puzzle
# 4369     4.3  21.0  Free    0.0       Everyone      Education
# 9033     4.3  20.0  Free    0.0       Everyone        Medical
# 185      4.3  30.0  Free    0.0       Everyone   Productivity
# 5862     4.3  19.0  Free    0.0       Everyone   Productivity
#
#          Last Updated         Current Ver         Android Ver      Installs
# 4534   August 3, 2018  Varies with device  Varies with device  1.000000e+09
# 9661   August 3, 2018  Varies with device  Varies with device  1.000000e+09
# 5731    July 31, 2018  Varies with device  Varies with device  1.000000e+09
# 6546   August 1, 2018  Varies with device  Varies with device  1.000000e+09
# 2701    July 15, 2018           10.322.16          4.1 and up  1.000000e+08
# ...               ...                 ...                 ...           ...
# 4372  August 23, 2017                 1.0          4.0 and up  1.000000e+01
# 4369    July 27, 2018           5.33.3669          5.0 and up  1.000000e+02
# 9033    July 14, 2018                 1.0          4.3 and up  1.000000e+01
# 185     June 28, 2018                 1.0          4.1 and up  1.000000e+01
# 5862    July 10, 2018              3.27.1          4.4 and up  1.000000e+02
#
# [9648 rows x 13 columns]

# %%
# check on statistical information of the dataframe
df.describe()
# Out:
#             Reviews       Rating         Size        Price      Installs
# count  9.648000e+03  9648.000000  9648.000000  9648.000000  9.648000e+03
# mean   2.170487e+05     4.192485    17.820208     1.098122  7.806898e+06
# std    1.832460e+06     0.496210    21.503151    16.861193  5.379975e+07
# min    0.000000e+00     1.000000     0.000000     0.000000  0.000000e+00
# 25%    2.500000e+01     4.000000     2.900000     0.000000  1.000000e+03
# 50%    9.745000e+02     4.300000     9.200000     0.000000  1.000000e+05
# 75%    2.949750e+04     4.500000    25.000000     0.000000  1.000000e+06
# max    7.815831e+07     5.000000   100.000000   400.000000  1.000000e+09

# %% [markdown]
# **EXPLORATORY DATA ANALYSIS AND VISUALIZATION**

# %%
# get the number of apps for each category
sns.set_style('darkgrid')
plt.figure(figsize=(10, 5))
sns.countplot(x='Category', data=df)
plt.title('Number of Apps Per Category')
plt.xticks(rotation=90)
plt.ylabel('Number of Apps')
plt.show()

# %% [markdown]
# From this plotting we know that most of the apps in the play store are from the categories of 'Family', ' Games' and 'Tools'.

# %%
# get the number of installs for each category
categories = df.groupby('Category')
category_installs_sum_df = categories[['Installs']].sum()
category_installs_sum_df = category_installs_sum_df.reset_index()  # to convert groupby object into dataframe

plt.figure(figsize=(10, 5))
sns.barplot(x='Category', y='Installs', data=category_installs_sum_df)
plt.xticks(rotation=90)
plt.ylabel('Installs (e+10)')
plt.title('Number of Installs For Each Category')
plt.show()

# %% [markdown]
# From this distribution plotting of number of installs for each category , we can see that most of the apps being downloaded & installed are from the categories of 'Games' and 'Communication'.

# %% [markdown]
# **Rating**

# %%
# show the distribution of rating
plt.figure(figsize=(10, 5))
sns.countplot(x='Rating', data=df)
plt.title('Rating Distribution')
plt.xticks(rotation=90)
plt.ylabel('Number of Apps')
plt.show()

# %% [markdown]
# ***From this distribution plotting, it implies that most of the apps in the Play Store are having rating higher than 4 or in the range of 4 to 4.7.:::***
#
# ---

# %%
# plot the graphs of reviews, size, installs and price per rating
rating_df =df.groupby('Rating').sum().reset_index()

fig, axes = plt.subplots(1, 4, figsize=(14, 4))

axes[0].plot(rating_df['Rating'], rating_df['Reviews'], 'r')
axes[0].set_xlabel('Rating')
axes[0].set_ylabel('Reviews')
axes[0].set_title('Reviews Per Rating')

axes[1].plot(rating_df['Rating'], rating_df['Size'], 'g')
axes[1].set_xlabel('Rating')
axes[1].set_ylabel('Size')
axes[1].set_title('Size Per Rating')

axes[2].plot(rating_df['Rating'], rating_df['Installs'], 'g')
axes[2].set_xlabel('Rating')
axes[2].set_ylabel('Installs (e+10)')
axes[2].set_title('Installs Per Rating')

axes[3].plot(rating_df['Rating'], rating_df['Price'], 'k')
axes[3].set_xlabel('Rating')
axes[3].set_ylabel('Price')
axes[3].set_title('Price Per Rating')

plt.tight_layout(pad=2)
plt.show()

# %% [markdown]
# ***Application Type***

# %%
# application type distribution
plt.figure(figsize=(11, 6))
sns.countplot(df['Type'])
plt.title('Type Distribution')
plt.ylabel('Number of Apps present')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **From the plot we can imply that majority of the apps in the Play Store are Free apps.**

# %%
# show the distribution of apps in term of their rating, size and type
plt.figure(figsize=(12, 6))
sns.scatterplot(df['Size'],
               df['Rating'],
               hue=df['Type'],
               s=50)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ***From this scatter plot, we can imply that majority of the free apps are small in size and having high rating. While for paid apps, we have quite equal distribution in term on size and rating.***\\:

# %%
# correlation
df.corr()
# Out:
#            Reviews    Rating      Size     Price  Installs
# Reviews   1.000000  0.050280  0.037812 -0.007597  0.625051
# Rating    0.050280  1.000000  0.027338 -0.018585  0.034393
# Size      0.037812  0.027338  1.000000 -0.015033 -0.007803
# Price    -0.007597 -0.018585 -0.015033  1.000000 -0.009418
# Installs  0.625051  0.034393 -0.007803 -0.009418  1.000000

# %%
fig, axes = plt.subplots(figsize=(8, 8))
sns.heatmap(df.corr(), ax=axes, annot=True, linewidths=0.1, fmt='.2f', square=True)
plt.show()

# %% [markdown]
# #Asking and Answering Questions
# 1. What is the top 5 apps on the basis of installs?

# %%
df = df.sort_values(by=['Installs'], ascending=False)
df.head(5)
# Out:
#                      App     Reviews          Category  Rating  Size  Type  \
# 4534            Facebook  78158306.0            SOCIAL     4.1   0.0  Free
# 5211       Google Photos  10859051.0       PHOTOGRAPHY     4.5   0.0  Free
# 5229             Google+   4831125.0            SOCIAL     4.2   0.0  Free
# 5122               Gmail   4604483.0     COMMUNICATION     4.3   0.0  Free
# 5221  Google Street View   2129707.0  TRAVEL_AND_LOCAL     4.2   0.0  Free
#
#       Price Content Rating          Genres    Last Updated  \
# 4534    0.0           Teen          Social  August 3, 2018
# 5211    0.0       Everyone     Photography  August 6, 2018
# 5229    0.0           Teen          Social   July 26, 2018
# 5122    0.0       Everyone   Communication  August 2, 2018
# 5221    0.0       Everyone  Travel & Local  August 6, 2018
#
#              Current Ver         Android Ver      Installs
# 4534  Varies with device  Varies with device  1.000000e+09
# 5211  Varies with device  Varies with device  1.000000e+09
# 5229  Varies with device  Varies with device  1.000000e+09
# 5122  Varies with device  Varies with device  1.000000e+09
# 5221  Varies with device  Varies with device  1.000000e+09

# %%
print(f'The 5 apps that have the most number of installs are: {", ".join(df["App"].head(5))}')
# Out:
# The 5 apps that have the most number of installs are: Facebook, Google Photos, Google+, Gmail, Google Street View

# %% [markdown]
#  2. What is the top 5 reviewed apps?

# %%
df = df.groupby(by=['App', 'Category', 'Rating'])[['Reviews']].sum().reset_index()
df = df.sort_values(by=['Reviews'], ascending=False)
df.head(5)
# Out:
#                                            App       Category  Rating  \
# 4324                                  Facebook         SOCIAL     4.1
# 9031                        WhatsApp Messenger  COMMUNICATION     4.4
# 5395                                 Instagram         SOCIAL     4.5
# 6158  Messenger – Text and Video Chat for Free  COMMUNICATION     4.0
# 2562                            Clash of Clans           GAME     4.6
#
#          Reviews
# 4324  78158306.0
# 9031  69119316.0
# 5395  66577446.0
# 6158  56646578.0
# 2562  44893888.0

# %%
print (f'The 5 apps that have the most number of the total reviews are : {",".join ( df["App"].head(5))}')
# Out:
# The 5 apps that have the most number of the total reviews are : Facebook,WhatsApp Messenger,Instagram,Messenger – Text and Video Chat for Free,Clash of Clans

# %% [markdown]
#  3. What is the top 3 most installed apps in Game category?

# %%
df = df[df['Category'] == 'GAME']
df
# Out:
#                                 App Category  Rating     Reviews
# 2562                 Clash of Clans     GAME     4.6  44893888.0
# 8071                 Subway Surfers     GAME     4.5  27725352.0
# 2559                   Clash Royale     GAME     4.6  23136735.0
# 2362               Candy Crush Saga     GAME     4.4  22430188.0
# 6426                 My Talking Tom     GAME     4.5  14892469.0
# ...                             ...      ...     ...         ...
# 2938                   DM Adventure     GAME     4.3         0.0
# 7802    Simple x3DS Emulator - BETA     GAME     4.3         0.0
# 1579               Bi-Tank Ads Free     GAME     4.3         0.0
# 9177                      YAKALA AY     GAME     4.3         0.0
# 909   Ay Vamos - PJ. Balvin - Piano     GAME     4.3         0.0
#
# [946 rows x 4 columns]

# %%
print(f'The top 3 most expensive apps in the GAME category are: {", ".join(df["App"].head(3))}')
# Out:
# The top 3 most expensive apps in the GAME category are: Clash of Clans, Subway Surfers, Clash Royale
